# %%
# !pip install kaggle
# !mkdir .kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.41.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2020.4.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.8.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.9)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.3)

# %%
import json
token = {"username":"fatemehy","key":"e6177841494493a99d3da8b61bab2fb1"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json
# !kaggle config set -n path -v{/content}
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets list
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# - path is now set to: {/content}
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                             title                                                size  lastUpdated          downloadCount
# --------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# allen-institute-for-ai/CORD-19-research-challenge               COVID-19 Open Research Dataset Challenge (CORD-19)    3GB  2020-06-10 00:09:23          71785
# roche-data-science-coalition/uncover                            UNCOVER COVID-19 Challenge                          179MB  2020-05-21 18:57:53          10483
# kwullum/fatal-police-shootings-in-the-us                        Fatal Police Shootings in the US                      1MB  2017-09-22 19:18:21          12617
# Cornell-University/arxiv                                        ArXiv Metadata                                        2GB  2020-05-06 23:18:35              2
# yash612/stockmarket-sentiment-dataset                           Stock-Market Sentiment Dataset                      201KB  2020-06-05 19:16:19              0
# cprete/covid19-open-datasets-for-brazil                         COVID-19 Open Datasets for Brazil                   139MB  2020-06-07 15:36:31              0
# mohitkr05/global-significant-earthquake-database-from-2150bc    Global Significant Earthquake Database from 2150BC  216KB  2020-06-08 09:41:18              0
# andrewmvd/global-education-statistics                           Global Education Statistics                          38MB  2020-06-06 04:35:48              0
# sudalairajkumar/daily-temperature-of-major-cities               Daily Temperature of Major Cities                    13MB  2020-06-05 07:34:48              0
# thoolihan/los-angeles-1992-riot-deaths-from-la-times            Los Angeles 1992 Riot Deaths from LA Times           16KB  2020-06-03 21:09:07              0
# imdevskp/hiv-aids-dataset                                       HIV AIDS Dataset                                     37KB  2020-06-11 12:59:45              0
# batjoker/zomato-restaurants-hyderabad                           Zomato Restaurants Hyderabad                          1MB  2020-06-08 15:11:39              0
# longnguyen2306/bacteria-detection-with-darkfield-microscopy     Bacteria detection with darkfield microscopy        162MB  2020-06-08 10:31:54              0
# paultimothymooney/minneapolis-police-stops-and-police-violence  Minneapolis Police Stops and Police Violence          8MB  2020-06-15 20:47:27              0
# jpmiller/police-violence-in-the-us                              US Police Violence & Fatal Shootings                 19MB  2020-06-16 14:19:33              0
# benroshan/factors-affecting-campus-placement                    Campus Recruitment                                    5KB  2020-04-11 11:09:02           5523
# bobbyscience/league-of-legends-diamond-ranked-games-10-min      League of Legends Diamond Ranked Games (10 min)     539KB  2020-04-13 13:53:02           2542
# fireballbyedimyrnmom/us-counties-covid-19-dataset               US counties COVID 19 dataset                          2MB  2020-06-16 13:52:58           7247
# divyansh22/flight-delay-prediction                              January Flight Delay Prediction                      23MB  2020-04-14 13:15:41           1850
# clmentbisaillon/fake-and-real-news-dataset                      Fake and real news dataset                           41MB  2020-03-26 18:51:15           4998

# %%
# !kaggle datasets list -s breast-cancer-wisconsin-data
# !kaggle datasets download -d uciml/breast-cancer-wisconsin-data    -p /content
# !unzip \*.zip
# import pandas as pd
# d = pd.read_csv('training.1600000.processed.noemoticon.csv')
# d.head()
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                        title                                          size  lastUpdated          downloadCount
# ---------------------------------------------------------  ---------------------------------------------  ----  -------------------  -------------
# uciml/breast-cancer-wisconsin-data                         Breast Cancer Wisconsin (Diagnostic) Data Set  49KB  2016-09-25 10:49:04          95007
# sarahvch/breast-cancer-wisconsin-prognostic-data-set       Breast Cancer Wisconsin (Prognostic) Data Set  49KB  2017-03-31 22:47:50           1601
# roustekbio/breast-cancer-csv                               Wisconsin Breast Cancer Database                6KB  2017-10-30 18:47:52           1777
# merishnasuwal/breast-cancer-prediction-dataset             Breast Cancer Prediction Dataset                8KB  2018-09-26 12:41:51           4615
# anacoder1/wisc-bc-data                                     Wisconsin Breast Cancer Dataset                49KB  2018-06-18 17:11:49            264
# hdza1991/breast-cancer-wisconsin-data-set                  Breast Cancer Wisconsin - Data Set             49KB  2018-01-08 04:07:46           1011
# salihacur/breastcancerwisconsin                            breast-cancer-wisconsin                         6KB  2020-03-16 12:29:40             49
# johnyquest/wisconsin-breast-cancer-cytology-features       Wisconsin breast cancer cytology features       6KB  2018-03-19 00:37:15            204
# ishandutta/breast-cancer-diagnostic-data-set               Breast Cancer Diagnostic Data Set              80KB  2020-05-26 18:29:10              0
# gimurthy/breast-cancer-wisconsin-title                     Breast Cancer Wisconsin                        49KB  2017-12-04 15:28:21            134
# priyanka841/breast-cancer-wisconsin                        Breast Cancer Wisconsin                         2MB  2020-04-16 11:03:04             70
# thulani96/breastcancer-wisconsin                           Breast-Cancer Wisconsin                         6KB  2017-12-14 00:07:39            157
# faroukbenarous/breast-cancer-wisconsin-diagnostic          Breast Cancer Wisconsin (Diagnostic)           49KB  2019-02-02 00:36:04             54
# washingtongold/wisconsin-breast-cancer-data-emp-ml-course  Wisconsin Breast Cancer Data - EMP ML Course   52KB  2020-04-01 21:51:54              9
# johnyquest/wisconsin-breast-cancer-cytology                Wisconsin Breast Cancer Cytology                6KB  2018-03-19 00:59:41            101
# omnamahshivai/dataset-breast-cancer-wisconsin              Dataset Breast Cancer Wisconsin                49KB  2018-09-21 10:11:37             32
# jeandedieunyandwi/breast-cancer-dataset-uci-ml             Breast Cancer Dataset UCI ML                   52KB  2020-04-19 09:31:16             12
# stevecoffie/uci-wisconsin-breast-cancer                    UCI Wisconsin Breast Cancer                    49KB  2020-06-05 23:49:32              0
# abhishekparida22/breastcancerwisconsin                     breast-cancer-wisconsin                        53KB  2020-04-28 12:17:36              2
# arnabsaha6/breast-cancer-wisconsin-dataset                 Breast Cancer Wisconsin Dataset                 6KB  2020-05-13 16:51:19              0
# Downloading breast-cancer-wisconsin-data.zip to /content
#   0% 0.00/48.6k [00:00<?, ?B/s]
# 100% 48.6k/48.6k [00:00<00:00, 19.0MB/s]
# Archive:  breast-cancer-wisconsin-data.zip
#   inflating: data.csv

# %%
# Load data into Pandas Dataframe
import pandas as pd
breast_cancer = pd.read_csv('data.csv')
breast_cancer
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
#Does the dataset include any missing values? If so, delete the missing values entries
breast_cancer.isnull().sum(axis = 0)
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
#Dropping Unnecessary Columns
breast_cancer.drop(['id'], axis = 1)
# Out:
#     diagnosis  radius_mean  ...  fractal_dimension_worst  Unnamed: 32
# 0           M        17.99  ...                  0.11890          NaN
# 1           M        20.57  ...                  0.08902          NaN
# 2           M        19.69  ...                  0.08758          NaN
# 3           M        11.42  ...                  0.17300          NaN
# 4           M        20.29  ...                  0.07678          NaN
# ..        ...          ...  ...                      ...          ...
# 564         M        21.56  ...                  0.07115          NaN
# 565         M        20.13  ...                  0.06637          NaN
# 566         M        16.60  ...                  0.07820          NaN
# 567         M        20.60  ...                  0.12400          NaN
# 568         B         7.76  ...                  0.07039          NaN
#
# [569 rows x 32 columns]

# %%
#Preprocessing
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(breast_cancer['diagnosis'])
breast_cancer['diagnosis']= encoder.transform(breast_cancer['diagnosis'])
# breast_cencer.drop('id',axis=1,inplace=True)
breast_cancer.drop('Unnamed: 32',axis=1,inplace=True)
# breast_cancer['diagnosis'] = breast_cancer['diagnosis'].map({'M':1,'B':0})
# breast_cancer.head()
breast_cancer.dropna()
# Out:
#            id  diagnosis  ...  symmetry_worst  fractal_dimension_worst
# 0      842302          1  ...          0.4601                  0.11890
# 1      842517          1  ...          0.2750                  0.08902
# 2    84300903          1  ...          0.3613                  0.08758
# 3    84348301          1  ...          0.6638                  0.17300
# 4    84358402          1  ...          0.2364                  0.07678
# ..        ...        ...  ...             ...                      ...
# 564    926424          1  ...          0.2060                  0.07115
# 565    926682          1  ...          0.2572                  0.06637
# 566    926954          1  ...          0.2218                  0.07820
# 567    927241          1  ...          0.4087                  0.12400
# 568     92751          0  ...          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
#Visualization
import matplotlib.pyplot as plt

#Scatter Plot

# create a figure with its axis
figure, axis = plt.subplots()
# scatter the “sepal length” on the x-axis and the “sepal width” on the y-axis
axis.scatter(breast_cancer['radius_mean'], breast_cancer['diagnosis'])
# set a title and labels
axis.set_title('breast_cancer Dataset')
axis.set_xlabel('radius_mean')
axis.set_ylabel('diagnosis')
# Out:
# Text(0, 0.5, 'diagnosis')

# %%
breast_cancer.corr()
# Out:
#                                id  ...  Unnamed: 32
# id                       1.000000  ...          NaN
# radius_mean              0.074626  ...          NaN
# texture_mean             0.099770  ...          NaN
# perimeter_mean           0.073159  ...          NaN
# area_mean                0.096893  ...          NaN
# smoothness_mean         -0.012968  ...          NaN
# compactness_mean         0.000096  ...          NaN
# concavity_mean           0.050080  ...          NaN
# concave points_mean      0.044158  ...          NaN
# symmetry_mean           -0.022114  ...          NaN
# fractal_dimension_mean  -0.052511  ...          NaN
# radius_se                0.143048  ...          NaN
# texture_se              -0.007526  ...          NaN
# perimeter_se             0.137331  ...          NaN
# area_se                  0.177742  ...          NaN
# smoothness_se            0.096781  ...          NaN
# compactness_se           0.033961  ...          NaN
# concavity_se             0.055239  ...          NaN
# concave points_se        0.078768  ...          NaN
# symmetry_se             -0.017306  ...          NaN
# fractal_dimension_se     0.025725  ...          NaN
# radius_worst             0.082405  ...          NaN
# texture_worst            0.064720  ...          NaN
# perimeter_worst          0.079986  ...          NaN
# area_worst               0.107187  ...          NaN
# smoothness_worst         0.010338  ...          NaN
# compactness_worst       -0.002968  ...          NaN
# concavity_worst          0.023203  ...          NaN
# concave points_worst     0.035174  ...          NaN
# symmetry_worst          -0.044224  ...          NaN
# fractal_dimension_worst -0.029866  ...          NaN
# Unnamed: 32                   NaN  ...          NaN
#
# [32 rows x 32 columns]

# %%
# breast_cancer.head
# breast_cancer['diagnosis'] = breast_cancer['diagnosis'].map({'M':1,'B':0})
# breast_cancer.head()
a=breast_cancer[breast_cancer.columns[1:]].corr() ['diagnosis'][:]
result=a[abs(a)>0.6]
result
#radious_mean,Area_mean, concavity_mean, radius_worst, perimiter_worst, concavity_worst, concave point_worst, compactness worst
# Out:
# diagnosis               1.000000
# radius_mean             0.730029
# perimeter_mean          0.742636
# area_mean               0.708984
# concavity_mean          0.696360
# concave points_mean     0.776614
# radius_worst            0.776454
# perimeter_worst         0.782914
# area_worst              0.733825
# concavity_worst         0.659610
# concave points_worst    0.793566
# Name: diagnosis, dtype: float64

# %%
breast_cancer2=breast_cancer[['diagnosis','radius_mean','perimeter_mean','area_mean','concavity_mean','concave points_mean','radius_worst','perimeter_worst','area_worst','concavity_worst','concave points_worst']]
breast_cancer2.head
# Out:
# <bound method NDFrame.head of      diagnosis  radius_mean  ...  concavity_worst  concave points_worst
# 0            1        17.99  ...           0.7119                0.2654
# 1            1        20.57  ...           0.2416                0.1860
# 2            1        19.69  ...           0.4504                0.2430
# 3            1        11.42  ...           0.6869                0.2575
# 4            1        20.29  ...           0.4000                0.1625
# ..         ...          ...  ...              ...                   ...
# 564          1        21.56  ...           0.4107                0.2216
# 565          1        20.13  ...           0.3215                0.1628
# 566          1        16.60  ...           0.3403                0.1418
# 567          1        20.60  ...           0.9387                0.2650
# 568          0         7.76  ...           0.0000                0.0000
#
# [569 rows x 11 columns]>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(breast_cancer2.iloc[:,1:])
y = breast_cancer2.iloc[:, 0].values
# print(X)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.2, random_state=0)
X_test, X_val, y_test, y_val = train_test_split(X_train, y_train, test_size=0.5, random_state=1)

# %%
#showing accuracy results on the modified dataset
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='gini', random_state=0).fit(X_train, y_train)
score = model.score(X_test, y_test)
y_pred = model.predict(X_test)
from sklearn.metrics import accuracy_score
print('accuracy_score: '+ str(accuracy_score(y_test, y_pred)))


from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=50, criterion='entropy', random_state=0).fit(X_train, y_train)
score = model.score(X_test, y_test)
y_pred = model.predict(X_test)
from sklearn.metrics import accuracy_score
print('accuracy_score: '+ str(accuracy_score(y_test, y_pred)))


from sklearn.svm import SVC
model = SVC(C=1.0, kernel='linear', gamma='auto', random_state=0).fit(X_train, y_train)
score = model.score(X_test, y_test)
y_pred = model.predict(X_test)
from sklearn.metrics import accuracy_score
print('accuracy_score: '+ str(accuracy_score(y_test, y_pred)))


from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3).fit(X_train, y_train)
score = model.score(X_test, y_test)
y_pred=model.predict(X_test)
from sklearn.metrics import accuracy_score
print('accuracy_score: '+ str(accuracy_score(y_test, y_pred)))

print('score ',score)
# Out:
# accuracy_score: 1.0
# accuracy_score: 1.0
# accuracy_score: 0.9955947136563876
# accuracy_score: 0.986784140969163
# score  0.986784140969163

# %%
#showing accuracy results on the original dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(breast_cancer.iloc[:,2:])
y = breast_cancer.iloc[:, 1].values
# print(y)
print(X)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
test_size=0.2, random_state=0)
X_test, X_val, y_test, y_val = train_test_split(X_train, y_train, test_size=0.5, random_state=1) 

from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='gini', random_state=0).fit(X_train, y_train)
score = model.score(X_test, y_test)
y_pred = model.predict(X_test)
from sklearn.metrics import accuracy_score
# print(y_test,y_pred)
print('recall score: '+ str(accuracy_score(y_test, y_pred)))

from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=50, criterion='entropy', random_state=0).fit(X_train, y_train)
score = model.score(X_test, y_test)
y_pred = model.predict(X_test)
from sklearn.metrics import accuracy_score
print('accuracy_score: '+ str(accuracy_score(y_test, y_pred)))

from sklearn.svm import SVC
model = SVC(C=1.0, kernel='linear', gamma='auto', random_state=0).fit(X_train, y_train)
score = model.score(X_test, y_test)
y_pred = model.predict(X_test)
from sklearn.metrics import accuracy_score
print('accuracy_score: '+ str(accuracy_score(y_test, y_pred)))

from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3).fit(X_train, y_train)
score = model.score(X_test, y_test)
y_pred=model.predict(X_test)
from sklearn.metrics import accuracy_score
print('accuracy_score: '+ str(accuracy_score(y_test, y_pred)))
# print('score: ',score)
# Out:
# [[ 1.09706398 -2.07333501  1.26993369 ...  2.29607613  2.75062224
#    1.93701461]
#  [ 1.82982061 -0.35363241  1.68595471 ...  1.0870843  -0.24388967
#    0.28118999]
#  [ 1.57988811  0.45618695  1.56650313 ...  1.95500035  1.152255
#    0.20139121]
#  ...
#  [ 0.70228425  2.0455738   0.67267578 ...  0.41406869 -1.10454895
#   -0.31840916]
#  [ 1.83834103  2.33645719  1.98252415 ...  2.28998549  1.91908301
#    2.21963528]
#  [-1.80840125  1.22179204 -1.81438851 ... -1.74506282 -0.04813821
#   -0.75120669]]
# recall score: 1.0
# accuracy_score: 1.0
# accuracy_score: 0.9955947136563876
# accuracy_score: 0.986784140969163
# score:  0.986784140969163
